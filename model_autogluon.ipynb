# %%
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
df = pd.read_csv('polish_train_split.csv')

target = 'company_bankrupt'

# %%
predictor = TabularPredictor(
    label=target,
    eval_metric= 'roc_auc'
).fit(
    df,
    presets='high_quality',
    time_limit=3600
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20251127_215258"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.1b20251126
# Python Version:     3.12.9
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26200
# CPU Count:          20
# Pytorch Version:    2.7.1+cpu
# CUDA Version:       CUDA is not available
# Memory Avail:       40.54 GB / 63.63 GB (63.7%)
# Disk Space Avail:   258.38 GB / 653.49 GB (39.5%)
# ...
# Presets specified: ['high_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# ...

# %%
test_df = pd.read_csv("polish_test_split.csv")

test_features = test_df.drop(columns=[target])
predictions = predictor.predict(test_features)

# %%
predictor.predict_proba(test_features)
# Out:
#              0         1
# 0     0.000929  0.999071
# 1     0.030140  0.969860
# 2     0.001091  0.998909
# 3     0.134805  0.865195
# 4     0.002183  0.997817
# ...        ...       ...
# 1965  0.031795  0.968205
# 1966  0.960106  0.039894
# 1967  0.667850  0.332150
# 1968  0.106812  0.893188
# 1969  0.543439  0.456561
#
# [1970 rows x 2 columns]

# %%
predictor.evaluate(test_df)
# Out:
# {'roc_auc': np.float64(0.9698064340239912),
#  'accuracy': 0.9771573604060914,
#  'balanced_accuracy': np.float64(0.8617895631535056),
#  'mcc': 0.809388134608787,
#  'f1': 0.987827968623208,
#  'precision': 0.9801395598497048,
#  'recall': 0.9956379498364231}

# %%
lb = predictor.leaderboard(silent=True)
print(lb)
# Out:
#                           model  score_val eval_metric  pred_time_val  \
# 0           WeightedEnsemble_L3   0.976438     roc_auc       1.804448
# 1     NeuralNetTorch_r30_BAG_L2   0.974393     roc_auc       1.553551
# 2     NeuralNetTorch_r41_BAG_L2   0.973437     roc_auc       1.551965
# 3           WeightedEnsemble_L2   0.973396     roc_auc       0.413562
# 4    NeuralNetTorch_r158_BAG_L2   0.973218     roc_auc       1.658924
# ..                          ...        ...         ...            ...
# 261   CatBoost_r137_BAG_L1_FULL        NaN     roc_auc            NaN
# 262   CatBoost_r128_BAG_L2_FULL        NaN     roc_auc            NaN
# 263   CatBoost_r128_BAG_L1_FULL        NaN     roc_auc            NaN
# 264        CatBoost_BAG_L2_FULL        NaN     roc_auc            NaN
# 265        CatBoost_BAG_L1_FULL        NaN     roc_auc            NaN
#
#        fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# ...
